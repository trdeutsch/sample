# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/mac/Desktop/Project/Sample/1553768847-housing.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df.replace(np.nan, df['total_bedrooms'].mean(), inplace = True)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 0             322         126         8.3252        NEAR BAY
# 1            2401        1138         8.3014        NEAR BAY
# 2             496         177         7.2574        NEAR BAY
# 3             558         219         5.6431        NEAR BAY
# 4             565         259         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  352100
# 3                  341300
# 4                  342200
# ...                   ...
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# 20639               89400
#
# [20640 rows x 10 columns]

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
def ocean_proximity (x):
    if x == '<1H OCEAN':
        return 1
    elif x == 'NEAR OCEAN':
        return 1
    elif x == 'NEAR BAY':
        return 1
    elif x == 'ISLAND':
        return 1
    elif x == 'INLAND':
        return 0
df['ocean_proximity'] = df.apply(lambda row: ocean_proximity(row['ocean_proximity']), axis = 1)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  ocean_proximity  \
# 0             322         126         8.3252                1
# 1            2401        1138         8.3014                1
# 2             496         177         7.2574                1
# 3             558         219         5.6431                1
# 4             565         259         3.8462                1
# ...           ...         ...            ...              ...
# 20635         845         330         1.5603                0
# 20636         356         114         2.5568                0
# 20637        1007         433         1.7000                0
# 20638         741         349         1.8672                0
# 20639        1387         530         2.3886                0
#
#        median_house_value
# 0                  452600
# 1                  358500
# 2                  352100
# 3                  341300
# 4                  342200
# ...                   ...
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# 20639               89400
#
# [20640 rows x 10 columns]

# %%
df['housing_median_age'] = df['housing_median_age'] / df['housing_median_age'].max()
df['total_rooms'] = df['total_rooms'] / df['total_rooms'].max()
df['total_bedrooms'] = df['total_bedrooms'] / df['total_bedrooms'].max()
df['population'] = df['population'] / df['population'].max()
df['households'] = df['households'] / df['households'].max()
df['median_income'] = df['median_income'] / df['median_income'].max()
df['median_house_value'] = df['median_house_value'] / df['median_house_value'].max()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df[['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income']], df[['median_house_value']], test_size = 0.2)

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

# %%
print('x_train.shape {}, y_train.shape {}'.format(x_train.shape, y_train.shape))
# Out:
# x_train.shape (16512, 6), y_train.shape (16512, 1)

# %%
def compute_cost (w, b, x, y, lambda_):
    m = x.shape[0]
    n = len(w)
    cost = 0
    reg_cost = 0
    
    for i in range(m):
        y_predict = np.dot(w, x[i]) + b
        cost += (y_predict - y[i]) ** 2
    cost = cost / (2 * m)
    
    for j in range(n):
        reg_cost += (w[j] ** 2)
    reg_cost = (lambda_ / (2 * m)) * reg_cost
    
    total_cost = cost + reg_cost
    print('Cost at optimal w is: ', total_cost)

# %%
w = np.random.rand(x_train.shape[1])
b = 0.5
lambda_ = 0.7
compute_cost(w, b, x_train, y_train, lambda_)
# Out:
# Cost at optimal w is:  [0.38739348]

# %%
def compute_gardient_descent(w, b, x, y, lambda_, learning_rate):
    m = x.shape[0]
    n = x.shape[1]
    
    dw = np.zeros((n, ))
    db = 0
    
    for i in range(m):
        y_predict = np.dot(w, x[i]) + b
        for j in range(n):
            dw[j] = dw[j] + (y_predict * x[i][j])
        db += y_predict - y[i]
    dw = dw / m
    db = db / m
    
    reg_dw = np.zeros((n,))
    for j in range(n):
        reg_dw[j] = (lambda_ / m) * w[j]
    dw = dw + reg_dw
    
    w = w - learning_rate * dw
    b = b - learning_rate * db 
   
    print('w is ', w)
    print('b is ', b)

# %%
w = np.random.rand(x_train.shape[1])
b = 0.5
lambda_ = 0.7
learning_rate = 0.001
compute_gardient_descent(w, b, x_train, y_train, lambda_, learning_rate)
# Out:
# w is  [0.94278559 0.81939804 0.1759495  0.02642696 0.79706498 0.32308846]
# b is  [0.49917473]

# %%
w = np.array([0.56662641, 0.34140304, 0.13303095, 0.38600769, 0.10100071, 0.04401588])
b = np.array([0.499532])

m = x_train.shape[0]
for i in range(m):
    print('prediction value', np.dot(w, x_train[i]) + b)
    print('target value', y_train[i])
# Out:
# prediction value [0.88196027]
# target value [0.5477989]
# prediction value [0.7570394]
# target value [0.30519939]
# prediction value [0.695543]
# target value [0.31159938]
# prediction value [0.90187035]
# target value [0.74539851]
# prediction value [0.92572133]
# target value [0.5519989]
# prediction value [0.68221515]
# target value [0.8501983]
# prediction value [0.69508957]
# target value [0.35499929]
# prediction value [0.93579966]
# target value [0.42339915]
# prediction value [0.89860671]
# target value [0.18099964]
# prediction value [0.78851374]
# target value [0.57039886]
# prediction value [0.87733197]
# target value [0.50899898]
# prediction value [1.16253446]
# target value [1.]
# prediction value [0.89705968]
# target value [1.]
# prediction value [0.96298455]
# target value [0.44339911]
# prediction value [0.7405656]
# target value [0.26199948]
# prediction value [0.96732735]
# target value [0.67639865]
# prediction value [1.1052832]
# target value [0.66059868]
# prediction value [0.81173323]
# target value [0.28139944]
# prediction value [0.77305571]
# target value [0.57319885]
# prediction value [1.05931693]
# target value [0.24679951]
# prediction value [0.99026228]
# target value [0.25459949]
# prediction value [0.76325488]
# target value [0.28679943]
# prediction value [1.07421152]
# target value [0.18759962]
# prediction value [0.78700839]
# target value [0.2499995]
# prediction value [0.91596093]
# target value [0.29159942]
# prediction value [0.85940375]
# target value [0.41119918]
# prediction value [0.62881879]
# target value [0.36079928]
# prediction value [0.88807518]
# target value [0.66159868]
# prediction value [0.67979334]
# target value [0.36259927]
# prediction value [0.94148421]
# target value [0.49619901]
# prediction value [0.62433726]
# target value [0.08999982]
# prediction value [1.09811478]
# target value [0.999998]
# prediction value [0.86596044]
# target value [0.35939928]
# prediction value [0.81525948]
# target value [0.52499895]
# prediction value [1.12018388]
# target value [0.51919896]
# prediction value [0.76555809]
# target value [0.26399947]
# prediction value [0.88283885]
# target value [0.61319877]
# prediction value [0.95059357]
# target value [0.34719931]
# prediction value [0.93644359]
# target value [0.25839948]
# prediction value [0.91848097]
# target value [0.26259947]
# prediction value [0.90728816]
# target value [1.]
# prediction value [0.95303431]
# target value [0.84399831]
# prediction value [0.83215941]
# target value [0.31659937]
# prediction value [0.79688403]
# target value [0.46119908]
# prediction value [0.92050367]
# target value [0.31559937]
# prediction value [0.85186134]
# target value [0.25999948]
# prediction value [0.81385095]
# target value [0.25699949]
# prediction value [0.70530631]
# target value [0.48639903]
# prediction value [0.72778252]
# target value [0.18319963]
# prediction value [0.77564924]
# target value [0.3975992]
# prediction value [0.7603429]
# target value [0.23959952]
# prediction value [0.97167201]
# target value [0.76479847]
# prediction value [0.77971822]
# target value [0.34499931]
# prediction value [0.73441275]
# target value [0.13499973]
# prediction value [1.03048957]
# target value [0.71719857]
# prediction value [1.04224195]
# target value [0.39579921]
# prediction value [0.80776296]
# target value [0.42659915]
# prediction value [0.83459934]
# target value [0.18979962]
# prediction value [0.79544598]
# target value [0.51779896]
# prediction value [0.79347766]
# target value [0.33619933]
# prediction value [1.10794871]
# target value [0.31339937]
# prediction value [0.72259139]
# target value [0.16779966]
# prediction value [0.96607821]
# target value [0.30839938]
# prediction value [0.78425259]
# target value [0.21099958]
# prediction value [0.84119631]
# target value [0.66039868]
# prediction value [0.85346851]
# target value [0.1475997]
# prediction value [1.06199173]
# target value [0.27579945]
# prediction value [0.76077473]
# target value [0.23659953]
# prediction value [0.75599703]
# target value [0.3489993]
# prediction value [1.10741177]
# target value [1.]
# prediction value [0.67005262]
# target value [0.30759938]
# prediction value [0.8391861]
# target value [0.38659923]
# prediction value [0.7350395]
# target value [0.18879962]
# prediction value [0.92222017]
# target value [0.14519971]
# prediction value [0.96136967]
# target value [0.69139862]
# prediction value [0.76631116]
# target value [0.32599935]
# prediction value [0.71124516]
# target value [0.52259895]
# prediction value [0.73465099]
# target value [0.13499973]
# prediction value [0.93052533]
# target value [0.32499935]
# prediction value [0.90559633]
# target value [0.41199918]
# prediction value [1.11426321]
# target value [1.]
# prediction value [0.88904909]
# target value [0.43159914]
# prediction value [0.72873196]
# target value [0.46359907]
# prediction value [0.74619724]
# target value [0.26599947]
# prediction value [0.94198575]
# target value [0.44319911]
# prediction value [0.82638529]
# target value [0.48419903]
# prediction value [0.66850044]
# target value [0.28139944]
# prediction value [0.76580473]
# target value [0.80679839]
# prediction value [0.60616884]
# target value [0.96659807]
# prediction value [1.09840475]
# target value [0.499999]
# prediction value [0.9977775]
# target value [0.37499925]
# prediction value [1.11566429]
# target value [0.44159912]
# prediction value [0.95837691]
# target value [0.16039968]
# prediction value [0.94497955]
# target value [0.53279893]
# prediction value [0.94276385]
# target value [0.43599913]
# prediction value [0.77669227]
# target value [0.19139962]
# prediction value [1.00030863]
# target value [0.31059938]
# prediction value [0.88553542]
# target value [0.32339935]
# prediction value [0.89663121]
# target value [0.14179972]
# prediction value [0.81349006]
# target value [0.49099902]
# prediction value [1.01666137]
# target value [0.28319943]
# prediction value [1.08420816]
# target value [0.21879956]
# prediction value [1.03389313]
# target value [0.31379937]
# prediction value [0.95293599]
# target value [0.39159922]
# prediction value [0.94289901]
# target value [0.38459923]
# prediction value [0.74228023]
# target value [0.42899914]
# prediction value [1.03535127]
# target value [0.21599957]
# prediction value [1.11941183]
# target value [1.]
# prediction value [0.84452339]
# target value [0.23699953]
# prediction value [1.02914213]
# target value [0.45259909]
# prediction value [0.86484457]
# target value [0.39379921]
# prediction value [0.7225096]
# target value [0.15739969]
# prediction value [1.07168232]
# target value [0.47659905]
# prediction value [0.89553505]
# target value [0.39159922]
# prediction value [0.79550835]
# target value [0.2509995]
# prediction value [0.83765172]
# target value [0.52499895]
# prediction value [0.90314482]
# target value [0.43119914]
# prediction value [0.76685593]
# target value [0.10599979]
# prediction value [0.70850411]
# target value [0.17499965]
# prediction value [0.95771577]
# target value [0.20419959]
# prediction value [0.84053085]
# target value [0.2523995]
# prediction value [0.75949862]
# target value [0.30279939]
# prediction value [0.77484017]
# target value [0.22259955]
# prediction value [0.95685623]
# target value [0.27499945]
# prediction value [0.76986057]
# target value [0.16519967]
# prediction value [0.94584012]
# target value [0.41239918]
# prediction value [0.89028159]
# target value [0.61379877]
# prediction value [0.9940835]
# target value [0.62359875]
# prediction value [0.77392369]
# target value [0.47479905]
# prediction value [0.78037341]
# target value [0.11839976]
# prediction value [1.05553907]
# target value [0.31639937]
# prediction value [0.89954834]
# target value [0.56339887]
# prediction value [0.73022367]
# target value [0.49379901]
# prediction value [0.86359839]
# target value [0.38419923]
# prediction value [1.05844786]
# target value [0.86959826]
# prediction value [1.06321476]
# target value [0.66659867]
# prediction value [0.84179089]
# target value [0.17499965]
# prediction value [0.83777848]
# target value [0.72179856]
# prediction value [0.91440575]
# target value [0.23519953]
# prediction value [0.72453637]
# target value [0.55559889]
# prediction value [0.8355921]
# target value [0.42499915]
# prediction value [0.93160105]
# target value [0.12659975]
# prediction value [0.76036636]
# target value [0.34179932]
# prediction value [0.96550205]
# target value [0.36739927]
# prediction value [0.91870446]
# target value [0.41899916]
# prediction value [1.00102123]
# target value [0.33399933]
# prediction value [0.72907286]
# target value [0.2499995]
# prediction value [0.99323115]
# target value [0.21659957]
# prediction value [0.99526052]
# target value [0.6485987]
# prediction value [0.92874056]
# target value [0.26719947]
# prediction value [0.8621554]
# target value [0.87819824]
# prediction value [0.75870966]
# target value [0.80499839]
# prediction value [0.86597603]
# target value [0.69239862]
# prediction value [0.83714005]
# target value [0.35699929]
# prediction value [0.93674501]
# target value [0.58859882]
# prediction value [0.74877854]
# target value [0.09499981]
# prediction value [0.77979979]
# target value [0.20279959]
# prediction value [0.89899217]
# target value [0.29259941]
# prediction value [0.96392041]
# target value [0.18479963]
# prediction value [0.95514539]
# target value [1.]
# prediction value [0.86261265]
# target value [0.22499955]
# prediction value [0.90048428]
# target value [0.15759968]
# prediction value [0.86980072]
# target value [0.18599963]
# prediction value [0.72088621]
# target value [0.20739959]
# prediction value [0.90213355]
# target value [0.13959972]
# prediction value [0.93664749]
# target value [0.10459979]
# prediction value [0.98123117]
# target value [0.41719917]
# prediction value [1.00900769]
# target value [0.93139814]
# prediction value [0.93553839]
# target value [0.29099942]
# prediction value [0.94033275]
# target value [0.37459925]
# prediction value [0.74435024]
# target value [0.26139948]
# prediction value [1.09145252]
# target value [0.18759962]
# prediction value [0.74620248]
# target value [0.2975994]
# prediction value [0.94578915]
# target value [0.36499927]
# prediction value [0.75793351]
# target value [0.46339907]
# prediction value [0.7556398]
# target value [0.58099884]
# prediction value [1.09333277]
# target value [0.46739907]
# prediction value [0.66201184]
# target value [0.27499945]
# prediction value [1.06547754]
# target value [0.17499965]
# prediction value [0.74108229]
# target value [0.26319947]
# prediction value [1.12689369]
# target value [0.16099968]
# prediction value [1.10381519]
# target value [0.19739961]
# prediction value [0.82432001]
# target value [0.73739853]
# prediction value [0.81347931]
# target value [0.45419909]
# prediction value [0.80163544]
# target value [0.33499933]
# prediction value [0.95031026]
# target value [0.36919926]
# prediction value [0.73265462]
# target value [0.55399889]
# prediction value [0.84161456]
# target value [0.45399909]
# prediction value [0.80338299]
# target value [0.78839842]
# prediction value [0.78939994]
# target value [0.52779894]
# prediction value [1.04969392]
# target value [0.42399915]
# prediction value [0.92689154]
# target value [0.38779922]
# prediction value [0.82125662]
# target value [0.19059962]
# prediction value [0.7609127]
# target value [0.25999948]
# prediction value [0.83967688]
# target value [0.24279951]
# prediction value [0.89676941]
# target value [0.48759902]
# prediction value [0.95747625]
# target value [0.499999]
# prediction value [0.94311818]
# target value [0.81239838]
# prediction value [0.96187856]
# target value [0.29099942]
# prediction value [0.99333231]
# target value [0.67079866]
# prediction value [1.14874197]
# target value [0.6999986]
# prediction value [0.69988396]
# target value [0.37359925]
# prediction value [0.91646438]
# target value [0.52059896]
# prediction value [0.92169242]
# target value [0.4513991]
# prediction value [0.95128707]
# target value [1.]
# prediction value [0.6932491]
# target value [0.22799954]
# prediction value [0.82380737]
# target value [0.17119966]
# prediction value [0.97526445]
# target value [0.37499925]
# prediction value [0.88990879]
# target value [0.50999898]
# prediction value [1.04576179]
# target value [1.]
# prediction value [0.91303618]
# target value [0.36999926]
# prediction value [0.89388229]
# target value [0.7499985]
# prediction value [0.81161866]
# target value [0.3485993]
# prediction value [0.94339265]
# target value [0.14039972]
# prediction value [1.15218373]
# target value [1.]
# prediction value [0.87368314]
# target value [0.30919938]
# prediction value [0.983642]
# target value [0.17579965]
# prediction value [0.76582904]
# target value [0.12719975]
# prediction value [0.90709315]
# target value [0.16559967]
# prediction value [0.93540669]
# target value [0.66379867]
# prediction value [0.84497958]
# target value [1.]
# prediction value [1.11259719]
# target value [0.20839958]
# prediction value [0.91571831]
# target value [1.]
# prediction value [0.81908391]
# target value [0.48439903]
# prediction value [0.91706006]
# target value [0.65879868]
# prediction value [0.93572151]
# target value [0.62819874]
# prediction value [0.9758461]
# target value [0.14139972]
# prediction value [0.69438356]
# target value [0.37579925]
# prediction value [1.02120972]
# target value [0.33019934]
# prediction value [0.79315043]
# target value [0.53919892]
# prediction value [0.94197116]
# target value [0.25299949]
# prediction value [0.90815632]
# target value [0.65259869]
# prediction value [0.80029896]
# target value [0.26759946]
# prediction value [0.84519049]
# target value [0.12059976]
# prediction value [0.93983861]
# target value [0.22299955]
# prediction value [0.73933901]
# target value [0.70799858]
# prediction value [0.70070038]
# target value [0.32979934]
# prediction value [0.72547038]
# target value [0.22699955]
# prediction value [0.7991857]
# target value [0.24659951]
# prediction value [0.8963526]
# target value [0.39159922]
# prediction value [0.78081298]
# target value [0.2983994]
# prediction value [0.9281226]
# target value [1.]
# prediction value [0.87647347]
# target value [0.17139966]
# prediction value [0.93970555]
# target value [0.35999928]
# prediction value [0.68283767]
# target value [0.26619947]
# prediction value [0.72286438]
# target value [0.3483993]
# prediction value [0.74466317]
# target value [0.21459957]
# prediction value [0.94361003]
# target value [0.3513993]
# prediction value [1.05362711]
# target value [1.]
# prediction value [0.94309017]
# target value [0.59479881]
# prediction value [1.10594996]
# target value [0.52319895]
# prediction value [1.08441099]
# target value [0.23999952]
# prediction value [0.92237947]
# target value [0.23439953]
# prediction value [1.14344664]
# target value [0.87779824]
# prediction value [0.86018255]
# target value [0.39599921]
# prediction value [0.91195195]
# target value [0.94159812]
# prediction value [0.88096268]
# target value [0.90419819]
# prediction value [0.76625342]
# target value [0.36719927]
# prediction value [0.75810167]
# target value [0.18479963]
# prediction value [0.76897551]
# target value [0.08999982]
# prediction value [0.83322028]
# target value [0.23459953]
# prediction value [0.85033507]
# target value [0.4489991]
# prediction value [1.00546782]
# target value [0.24159952]
# prediction value [0.9471875]
# target value [0.30299939]
# prediction value [0.80310846]
# target value [0.32939934]
# prediction value [0.7947493]
# target value [0.34739931]
# prediction value [1.02331593]
# target value [0.26359947]
# prediction value [0.93618032]
# target value [0.44199912]
# prediction value [0.74158166]
# target value [0.36779926]
# prediction value [0.83155231]
# target value [0.43659913]
# prediction value [1.04536103]
# target value [1.]
# prediction value [0.75527794]
# target value [0.35539929]
# prediction value [0.61563631]
# target value [0.19439961]
# prediction value [0.9965799]
# target value [0.36059928]
# prediction value [1.00663014]
# target value [0.6999986]
# prediction value [0.89884137]
# target value [1.]
# prediction value [0.83562469]
# target value [0.29219942]
# prediction value [0.77382428]
# target value [0.7999984]
# prediction value [0.75655163]
# target value [0.64039872]
# prediction value [0.77945709]
# target value [0.13639973]
# prediction value [0.90131365]
# target value [0.36759926]
# prediction value [0.91266678]
# target value [0.21619957]
# prediction value [0.88043204]
# target value [0.22539955]
# prediction value [0.74216423]
# target value [0.26439947]
# prediction value [0.9055898]
# target value [0.13739973]
# prediction value [0.7606236]
# target value [0.37739925]
# prediction value [0.82868859]
# target value [0.32419935]
# prediction value [0.994751]
# target value [0.28139944]
# prediction value [0.85815175]
# target value [0.19059962]
# prediction value [0.71872195]
# target value [0.18439963]
# prediction value [0.86558758]
# target value [0.93279813]
# prediction value [0.74894638]
# target value [0.24139952]
# prediction value [0.9994839]
# target value [0.23239954]
# prediction value [0.77533588]
# target value [0.78419843]
# prediction value [0.80266728]
# target value [0.43999912]
# prediction value [1.09249776]
# target value [0.63339873]
# prediction value [0.98356291]
# target value [1.]
# prediction value [0.93109856]
# target value [1.]
# prediction value [0.85187771]
# target value [0.11119978]
# prediction value [1.00806416]
# target value [0.42779914]
# prediction value [0.92806992]
# target value [0.6999986]
# prediction value [0.94469206]
# target value [0.32219936]
# prediction value [0.76593202]
# target value [0.56019888]
# prediction value [0.64440549]
# target value [0.23659953]
# prediction value [0.9279609]
# target value [0.15259969]
# prediction value [0.75894695]
# target value [0.54639891]
# prediction value [0.78079842]
# target value [0.17499965]
# prediction value [1.15594007]
# target value [0.77279845]
# prediction value [0.73927875]
# target value [0.62879874]
# prediction value [0.84378421]
# target value [1.]
# prediction value [0.8748909]
# target value [0.46519907]
# prediction value [0.81926174]
# target value [0.55639889]
# prediction value [0.73396988]
# target value [0.5505989]
# prediction value [0.82304806]
# target value [0.57039886]
# prediction value [0.77862024]
# target value [0.31659937]
# prediction value [0.9493024]
# target value [0.30779938]
# prediction value [0.88623835]
# target value [0.72119856]
# prediction value [0.94416999]
# target value [0.75319849]
# prediction value [0.72045511]
# target value [0.21879956]
# prediction value [0.79515921]
# target value [1.]
# prediction value [0.73478856]
# target value [0.28319943]
# prediction value [0.89968522]
# target value [0.63379873]
# prediction value [1.01160542]
# target value [0.15939968]
# prediction value [0.79466065]
# target value [0.16499967]
# prediction value [1.11413125]
# target value [0.63679873]
# prediction value [0.73768414]
# target value [0.14499971]
# prediction value [0.88237163]
# target value [1.]
# prediction value [0.81085181]
# target value [0.71259857]
# prediction value [0.939566]
# target value [0.36639927]
# prediction value [0.629491]
# target value [0.27699945]
# prediction value [0.71750733]
# target value [0.18679963]
# prediction value [1.10411281]
# target value [0.19679961]
# prediction value [0.73850052]
# target value [0.4483991]
# prediction value [0.97256819]
# target value [0.38399923]
# prediction value [0.75023278]
# target value [0.5483989]
# prediction value [0.9728136]
# target value [0.17239966]
# prediction value [1.07336992]
# target value [0.45519909]
# prediction value [0.73358357]
# target value [0.68299863]
# prediction value [0.88414845]
# target value [1.]
# prediction value [0.96820696]
# target value [0.56159888]
# prediction value [0.82718529]
# target value [0.48239904]
# prediction value [0.92816913]
# target value [0.31939936]
# prediction value [0.84396801]
# target value [0.4493991]
# prediction value [0.8931157]
# target value [0.33099934]
# prediction value [0.67209294]
# target value [0.12279975]
# prediction value [0.839099]
# target value [0.55699889]
# prediction value [0.9583477]
# target value [0.96299807]
# prediction value [0.86349884]
# target value [0.30999938]
# prediction value [0.73229245]
# target value [0.3017994]
# prediction value [1.07531147]
# target value [0.19279961]
# prediction value [1.02735303]
# target value [0.40459919]
# prediction value [0.84996523]
# target value [0.43839912]
# prediction value [0.97509048]
# target value [0.22799954]
# prediction value [1.1598621]
# target value [0.32499935]
# prediction value [0.9183556]
# target value [0.11799976]
# prediction value [0.63791311]
# target value [0.10759978]
# prediction value [1.1384216]
# target value [0.68699863]
# prediction value [0.68521751]
# target value [0.89479821]
# prediction value [0.95279058]
# target value [0.55879888]
# prediction value [0.81824619]
# target value [0.25499949]
# prediction value [0.74741373]
# target value [0.15839968]
# prediction value [0.81857824]
# target value [0.75439849]
# prediction value [0.78944092]
# target value [0.63699873]
# prediction value [1.0982072]
# target value [0.30919938]
# prediction value [1.14046757]
# target value [0.82919834]
# prediction value [0.79015751]
# target value [0.5483989]
# prediction value [0.84663579]
# target value [0.45839908]
# prediction value [1.04292997]
# target value [0.38819922]
# prediction value [1.13015664]
# target value [0.5491989]
# prediction value [0.7862923]
# target value [0.14659971]
# prediction value [1.00169597]
# target value [0.39159922]
# prediction value [1.03387237]
# target value [0.6991986]
# prediction value [0.85148164]
# target value [0.19739961]
# prediction value [1.0093526]
# target value [0.73219854]
# prediction value [0.7216726]
# target value [0.25519949]
# prediction value [0.78442856]
# target value [0.47899904]
# prediction value [0.83490313]
# target value [0.17759964]
# prediction value [0.65308426]
# target value [0.29259941]
# prediction value [0.86529287]
# target value [0.73339853]
# prediction value [0.94967472]
# target value [0.43779912]
# prediction value [0.81433653]
# target value [0.28679943]
# prediction value [0.91660015]
# target value [0.1999996]
# prediction value [0.92346207]
# target value [0.68079864]
# prediction value [1.10911978]
# target value [0.45819908]
# prediction value [0.96233065]
# target value [0.14419971]
# prediction value [0.98350489]
# target value [0.62819874]
# prediction value [0.92037623]
# target value [0.62499875]
# prediction value [0.66907756]
# target value [0.14039972]
# prediction value [0.84311592]
# target value [0.36259927]
# prediction value [0.82080183]
# target value [0.25939948]
# prediction value [0.68906365]
# target value [0.43739913]
# prediction value [0.9007623]
# target value [0.36279927]
# prediction value [1.01732306]
# target value [0.52759894]
# prediction value [0.80853251]
# target value [0.19299961]
# prediction value [0.74348104]
# target value [0.13499973]
# prediction value [0.82809651]
# target value [0.5487989]
# prediction value [0.88875206]
# target value [0.42339915]
# prediction value [1.01324095]
# target value [0.47879904]
# prediction value [0.70457022]
# target value [0.18359963]
# prediction value [0.90585944]
# target value [0.44339911]
# prediction value [1.1502068]
# target value [0.53759892]
# prediction value [0.71682961]
# target value [0.43879912]
# prediction value [0.64916024]
# target value [0.51339897]
# prediction value [1.1223237]
# target value [0.83379833]
# prediction value [0.72518205]
# target value [0.2475995]
# prediction value [0.77854677]
# target value [0.28759942]
# prediction value [1.11514754]
# target value [0.21099958]
# prediction value [0.79514829]
# target value [0.87599825]
# prediction value [0.89649458]
# target value [0.22499955]
# prediction value [0.91266788]
# target value [0.33519933]
# prediction value [0.73481612]
# target value [0.21779956]
# prediction value [0.7873509]
# target value [0.32999934]
# prediction value [0.88771095]
# target value [0.4477991]
# prediction value [0.71725967]
# target value [0.1999996]
# prediction value [0.96594206]
# target value [0.4499991]
# prediction value [0.95775132]
# target value [0.73379853]
# prediction value [0.7928157]
# target value [0.40679919]
# prediction value [1.08143284]
# target value [0.75619849]
# prediction value [0.70519499]
# target value [0.29279941]
# prediction value [1.10076946]
# target value [0.36459927]
# prediction value [0.86214492]
# target value [0.64739871]
# prediction value [0.82609998]
# target value [0.28799942]
# prediction value [1.01372311]
# target value [0.3999992]
# prediction value [0.97918401]
# target value [1.]
# prediction value [1.10156934]
# target value [0.22499955]
# prediction value [1.11939492]
# target value [0.43459913]
# prediction value [0.63625839]
# target value [0.52279895]
# prediction value [0.94110685]
# target value [0.2999994]
# prediction value [0.86589386]
# target value [0.54519891]
# prediction value [1.10117559]
# target value [0.47119906]
# prediction value [0.83733891]
# target value [0.33779932]
# prediction value [0.75694691]
# target value [0.11759976]
# prediction value [0.95415718]
# target value [0.27319945]
# prediction value [0.92325996]
# target value [0.40479919]
# prediction value [0.88206738]
# target value [0.35579929]
# prediction value [0.91891735]
# target value [0.76299847]
# prediction value [0.73077838]
# target value [0.15999968]
# prediction value [0.66480921]
# target value [0.31339937]
# prediction value [1.04887543]
# target value [0.37639925]
# prediction value [1.110773]
# target value [1.]
# prediction value [0.79899684]
# target value [0.1475997]
# prediction value [0.86539304]
# target value [0.28279943]
# prediction value [0.97441149]
# target value [0.48619903]
# prediction value [0.88020357]
# target value [0.31799936]
# prediction value [0.84952749]
# target value [0.53999892]
# prediction value [0.6542531]
# target value [0.14459971]
# prediction value [1.0274162]
# target value [0.18119964]
# prediction value [0.91328022]
# target value [0.32779934]
# prediction value [0.87112358]
# target value [0.43339913]
# prediction value [0.77601337]
# target value [0.18759962]
# prediction value [0.61679232]
# target value [0.31179938]
# prediction value [0.78920444]
# target value [0.62399875]
# prediction value [0.74930489]
# target value [0.11119978]
# prediction value [0.96848051]
# target value [0.10519979]
# prediction value [0.96714742]
# target value [0.44179912]
# prediction value [0.68439705]
# target value [0.0975998]
# prediction value [0.8198663]
# target value [0.56939886]
# prediction value [0.97040384]
# target value [0.33799932]
# prediction value [0.72206722]
# target value [0.29399941]
# prediction value [0.72534516]
# target value [0.26999946]
# prediction value [0.82425166]
# target value [0.35499929]
# prediction value [0.88583205]
# target value [0.8521983]
# prediction value [1.04507528]
# target value [0.10619979]
# prediction value [1.0105118]
# target value [1.]
# prediction value [0.85004459]
# target value [0.59099882]
# prediction value [0.88744292]
# target value [0.30459939]
# prediction value [0.76974256]
# target value [1.]
# prediction value [0.90137164]
# target value [0.2011996]
# prediction value [0.92487731]
# target value [0.50699899]
# prediction value [0.58959064]
# target value [1.]
# prediction value [0.8782007]
# target value [0.59259881]
# prediction value [1.10786203]
# target value [0.37779924]
# prediction value [0.98778453]
# target value [0.16139968]
# prediction value [0.76698258]
# target value [0.21519957]
# prediction value [1.03087765]
# target value [0.50719899]
# prediction value [0.9421691]
# target value [0.56419887]
# prediction value [0.69760439]
# target value [0.16199968]
# prediction value [0.95415535]
# target value [0.22739955]
# prediction value [0.73759524]
# target value [0.33479933]
# prediction value [0.98178924]
# target value [0.11659977]
# prediction value [0.69099868]
# target value [0.25279949]
# prediction value [0.91510549]
# target value [0.19339961]
# prediction value [1.12650546]
# target value [0.51719897]
# prediction value [1.03050351]
# target value [0.33599933]
# prediction value [1.0159451]
# target value [0.1503997]
# prediction value [0.7981609]
# target value [0.12079976]
# prediction value [0.81818421]
# target value [0.4491991]
# prediction value [0.69653406]
# target value [0.22219956]
# prediction value [1.11053931]
# target value [0.8499983]
# prediction value [0.84971925]
# target value [0.28499943]
# prediction value [0.8625727]
# target value [0.65499869]
# prediction value [1.0792751]
# target value [0.19659961]
# prediction value [0.70791879]
# target value [0.3007994]
# prediction value [1.07631571]
# target value [0.08499983]
# prediction value [1.08904527]
# target value [0.62939874]
# prediction value [0.85999937]
# target value [0.12319975]
# prediction value [0.93457461]
# target value [0.33099934]
# prediction value [0.86835997]
# target value [0.2015996]
# prediction value [0.91913543]
# target value [0.10519979]
# prediction value [0.75050259]
# target value [0.45599909]
# prediction value [1.08737665]
# target value [0.32139936]
# prediction value [0.93331246]
# target value [0.70719859]
# prediction value [1.10415272]
# target value [0.50299899]
# prediction value [0.85271671]
# target value [0.47879904]
# prediction value [0.95787047]
# target value [0.89239822]
# prediction value [0.84079576]
# target value [0.09519981]
# prediction value [0.67113104]
# target value [0.30599939]
# prediction value [0.86961198]
# target value [0.27079946]
# prediction value [0.85952427]
# target value [0.84579831]
# prediction value [0.81891895]
# target value [0.501799]
# prediction value [0.85420061]
# target value [0.62799874]
# prediction value [0.86015301]
# target value [0.36099928]
# prediction value [0.79048402]
# target value [0.43939912]
# prediction value [0.83697118]
# target value [0.58699883]
# prediction value [0.74980794]
# target value [0.35619929]
# prediction value [0.97591805]
# target value [0.71699857]
# prediction value [1.02284161]
# target value [0.59059882]
# prediction value [0.93958246]
# target value [0.33259933]
# prediction value [0.6814118]
# target value [0.22059956]
# prediction value [0.93607387]
# target value [0.91699817]
# prediction value [0.91086464]
# target value [1.]
# prediction value [0.72948394]
# target value [0.0999998]
# prediction value [0.82863573]
# target value [0.45759908]
# prediction value [0.74586034]
# target value [0.27499945]
# prediction value [0.92208641]
# target value [0.19599961]
# prediction value [0.89555404]
# target value [0.2999994]
# prediction value [0.70975412]
# target value [0.21659957]
# prediction value [1.14247584]
# target value [1.]
# prediction value [0.7476123]
# target value [0.13119974]
# prediction value [1.12503226]
# target value [1.]
# prediction value [0.75397428]
# target value [0.45299909]
# prediction value [1.02139001]
# target value [0.25939948]
# prediction value [0.93517149]
# target value [0.37099926]
# prediction value [0.85722882]
# target value [0.71219858]
# prediction value [0.81059435]
# target value [0.20319959]
# prediction value [1.12069943]
# target value [0.37879924]
# prediction value [1.03864529]
# target value [0.67379865]
# prediction value [0.91202709]
# target value [0.51459897]
# prediction value [0.73270739]
# target value [0.25879948]
# prediction value [0.93294919]
# target value [0.37879924]
# prediction value [0.84220139]
# target value [0.22499955]
# prediction value [0.83697769]
# target value [0.29239942]
# prediction value [1.09463028]
# target value [0.8999982]
# prediction value [0.95219606]
# target value [1.]
# prediction value [0.94023555]
# target value [0.37039926]
# prediction value [1.05265475]
# target value [0.62979874]
# prediction value [0.80367877]
# target value [0.28999942]
# prediction value [0.96535585]
# target value [0.43599913]
# prediction value [0.88540147]
# target value [0.50619899]
# prediction value [0.76692411]
# target value [0.3475993]
# prediction value [0.73885938]
# target value [0.25339949]
# prediction value [0.68630954]
# target value [0.27499945]
# prediction value [0.71645032]
# target value [0.34719931]
# prediction value [0.89763265]
# target value [1.]
# prediction value [1.04252583]
# target value [0.22819954]
# prediction value [0.83042868]
# target value [0.6517987]
# prediction value [0.83243015]
# target value [0.31519937]
# prediction value [0.93436107]
# target value [0.39459921]
# prediction value [0.77848921]
# target value [0.87279825]
# prediction value [1.14550996]
# target value [0.54279891]
# prediction value [0.78246774]
# target value [0.12919974]
# prediction value [0.63010499]
# target value [0.77999844]
# prediction value [0.94938061]
# target value [0.81399837]
# prediction value [0.95267614]
# target value [0.34199932]
# prediction value [0.89335714]
# target value [1.]
# prediction value [0.73747782]
# target value [0.18559963]
# prediction value [0.80412746]
# target value [0.2523995]
# prediction value [0.8082396]
# target value [0.39619921]
# prediction value [1.04197437]
# target value [0.10759978]
# prediction value [0.79826352]
# target value [0.5499989]
# prediction value [0.88084475]
# target value [0.17739965]
# prediction value [0.93349603]
# target value [0.46399907]
# prediction value [0.91532522]
# target value [0.19719961]
# prediction value [0.81174159]
# target value [0.66539867]
# prediction value [0.92180914]
# target value [1.]
# prediction value [0.94077957]
# target value [0.25759948]
# prediction value [0.87178903]
# target value [0.40859918]
# prediction value [0.75840292]
# target value [0.24739951]
# prediction value [0.8956178]
# target value [0.13599973]
# prediction value [0.99029417]
# target value [1.]
# prediction value [0.83117635]
# target value [0.31899936]
# prediction value [0.685768]
# target value [0.17999964]
# prediction value [0.93016467]
# target value [0.38139924]
# prediction value [1.06461806]
# target value [0.53539893]
# prediction value [0.67645365]
# target value [0.36639927]
# prediction value [0.93450833]
# target value [0.33559933]
# prediction value [0.80842852]
# target value [0.34679931]
# prediction value [1.02191498]
# target value [0.16399967]
# prediction value [0.817005]
# target value [0.5499989]
# prediction value [0.96118841]
# target value [0.29259941]
# prediction value [0.96948012]
# target value [0.57919884]
# prediction value [0.9724788]
# target value [1.]
# prediction value [1.02748238]
# target value [0.26819946]
# prediction value [1.03457676]
# target value [0.47099906]
# prediction value [0.66144808]
# target value [0.60939878]
# prediction value [0.82135308]
# target value [0.24399951]
# prediction value [1.09768991]
# target value [0.38159924]
# prediction value [1.06729954]
# target value [1.]
# prediction value [0.86520778]
# target value [0.32859934]
# prediction value [1.09541855]
# target value [0.23219954]
# prediction value [0.84365918]
# target value [0.16319967]
# prediction value [0.8812941]
# target value [0.32419935]
# prediction value [1.09473248]
# target value [0.41259917]
# prediction value [0.87753581]
# target value [0.15659969]
# prediction value [0.97446359]
# target value [1.]
# prediction value [0.74420369]
# target value [0.24479951]
# prediction value [0.71358771]
# target value [1.]
# prediction value [0.93257808]
# target value [0.1511997]
# prediction value [0.79280006]
# target value [0.25859948]
# prediction value [0.78552005]
# target value [0.49499901]
# prediction value [0.77788642]
# target value [0.14479971]
# prediction value [0.93435214]
# target value [0.55859888]
# prediction value [0.97897586]
# target value [0.27639945]
# prediction value [0.86781164]
# target value [0.35979928]
# prediction value [0.91066773]
# target value [0.32239936]
# prediction value [0.76517006]
# target value [0.20279959]
# prediction value [0.74983253]
# target value [0.36659927]
# prediction value [0.81629029]
# target value [0.43699913]
# prediction value [1.10500948]
# target value [0.42919914]
# prediction value [0.73015464]
# target value [0.36259927]
# prediction value [1.01907303]
# target value [0.21719957]
# prediction value [0.71153362]
# target value [0.19059962]
# prediction value [0.96305818]
# target value [0.23539953]
# prediction value [0.83891672]
# target value [0.8999982]
# prediction value [0.94979044]
# target value [0.48839902]
# prediction value [1.04962408]
# target value [0.46079908]
# prediction value [0.8819212]
# target value [0.3517993]
# prediction value [0.90516315]
# target value [0.30859938]
# prediction value [0.68613551]
# target value [0.31639937]
# prediction value [0.89909532]
# target value [1.]
# prediction value [0.84988485]
# target value [0.4499991]
# prediction value [1.0536376]
# target value [0.62799874]
# prediction value [0.64042763]
# target value [0.62099876]
# prediction value [0.68069773]
# target value [0.6011988]
# prediction value [0.88436389]
# target value [0.4019992]
# prediction value [0.84677198]
# target value [0.25879948]
# prediction value [0.75657247]
# target value [0.58179884]
# prediction value [0.92868769]
# target value [0.49199902]
# prediction value [0.72614243]
# target value [0.47159906]
# prediction value [0.98422726]
# target value [0.18119964]
# prediction value [0.83081076]
# target value [0.38339923]
# prediction value [0.79545827]
# target value [0.28379943]
# prediction value [0.90304032]
# target value [0.26759946]
# prediction value [1.05910219]
# target value [0.8999982]
# prediction value [0.88555707]
# target value [0.37559925]
# prediction value [0.85009126]
# target value [0.66799866]
# prediction value [0.90555801]
# target value [0.22239956]
# prediction value [0.92910481]
# target value [0.17659965]
# prediction value [0.95520748]
# target value [0.15919968]
# prediction value [1.07606585]
# target value [0.56819886]
# prediction value [0.82068367]
# target value [0.38219924]
# prediction value [0.99781775]
# target value [0.19719961]
# prediction value [0.81242151]
# target value [0.68159864]
# prediction value [1.10062393]
# target value [0.18559963]
# prediction value [0.92630824]
# target value [0.44539911]
# prediction value [0.77565231]
# target value [0.33599933]
# prediction value [0.84586236]
# target value [0.33159934]
# prediction value [0.74498898]
# target value [0.19259961]
# prediction value [0.67771878]
# target value [0.11579977]
# prediction value [0.94232242]
# target value [0.32039936]
# prediction value [0.79142581]
# target value [0.65319869]
# prediction value [0.84797657]
# target value [0.22699955]
# prediction value [0.82354468]
# target value [0.14059972]
# prediction value [0.82348149]
# target value [0.89079822]
# prediction value [1.14178427]
# target value [0.72319855]
# prediction value [0.81917542]
# target value [0.46159908]
# prediction value [0.84003008]
# target value [0.16119968]
# prediction value [0.83336796]
# target value [0.31659937]
# prediction value [0.88111928]
# target value [0.10979978]
# prediction value [0.75287716]
# target value [0.44239912]
# prediction value [0.95415077]
# target value [0.28459943]
# prediction value [0.88820322]
# target value [0.57319885]
# prediction value [0.70500801]
# target value [0.17139966]
# prediction value [0.81523479]
# target value [0.11559977]
# prediction value [0.95040037]
# target value [0.12179976]
# prediction value [0.96425833]
# target value [0.31839936]
# prediction value [1.10980583]
# target value [0.58759882]
# prediction value [0.76589887]
# target value [0.19279961]
# prediction value [0.66485761]
# target value [0.10659979]
# prediction value [0.96884444]
# target value [0.39039922]
# prediction value [0.80362212]
# target value [0.16619967]
# prediction value [0.92185149]
# target value [0.19539961]
# prediction value [0.80853009]
# target value [0.67939864]
# prediction value [0.7542343]
# target value [0.37439925]
# prediction value [0.94584907]
# target value [0.56379887]
# prediction value [0.93292877]
# target value [0.47859904]
# prediction value [0.84621998]
# target value [0.36819926]
# prediction value [1.10444607]
# target value [0.73259853]
# prediction value [0.94693329]
# target value [0.66679867]
# prediction value [1.01135528]
# target value [0.6515987]
# prediction value [0.98479878]
# target value [0.13579973]
# prediction value [0.72069939]
# target value [0.38819922]
# prediction value [1.01724479]
# target value [0.64539871]
# prediction value [0.93226331]
# target value [0.82499835]
# prediction value [1.06981743]
# target value [0.11999976]
# prediction value [1.02123126]
# target value [0.78879842]
# prediction value [1.07693846]
# target value [0.27499945]
# prediction value [0.86159047]
# target value [0.71759856]
# prediction value [0.96157577]
# target value [0.42959914]
# prediction value [0.68813627]
# target value [0.16179968]
# prediction value [0.9349092]
# target value [0.37499925]
# prediction value [0.92784758]
# target value [0.37499925]
# prediction value [0.87955966]
# target value [0.1977996]
# prediction value [0.65336089]
# target value [0.36159928]
# prediction value [0.76214028]
# target value [0.41999916]
# prediction value [0.75995667]
# target value [0.2009996]
# prediction value [0.64816192]
# target value [0.67099866]
# prediction value [0.64224398]
# target value [0.52759894]
# prediction value [0.96682892]
# target value [0.13499973]
# prediction value [0.82044033]
# target value [0.87179826]
# prediction value [1.04676004]
# target value [0.27619945]
# prediction value [1.14317443]
# target value [1.]
# prediction value [0.92145321]
# target value [0.32499935]
# prediction value [0.93153314]
# target value [0.31999936]
# prediction value [0.8786819]
# target value [0.3999992]
# prediction value [1.016218]
# target value [0.29419941]
# prediction value [0.83414539]
# target value [0.25579949]
# prediction value [0.83884612]
# target value [0.64139872]
# prediction value [1.00483729]
# target value [0.33419933]
# prediction value [0.68301997]
# target value [0.59319881]
# prediction value [0.95175236]
# target value [0.31259937]
# prediction value [0.87114699]
# target value [0.32799934]
# prediction value [0.84214276]
# target value [0.21139958]
# prediction value [1.02416657]
# target value [0.54139892]
# prediction value [0.62317997]
# target value [0.17039966]
# prediction value [0.91780235]
# target value [0.41779916]
# prediction value [0.87058831]
# target value [0.13279973]
# prediction value [0.86916831]
# target value [0.20819958]
# prediction value [0.94008296]
# target value [0.17339965]
# prediction value [0.97810413]
# target value [0.16699967]
# prediction value [0.76139734]
# target value [0.18519963]
# prediction value [1.08978117]
# target value [0.19339961]
# prediction value [1.0206549]
# target value [0.22079956]
# prediction value [0.85059233]
# target value [0.21559957]
# prediction value [0.97667164]
# target value [0.5999988]
# prediction value [0.76029703]
# target value [0.18379963]
# prediction value [0.87286902]
# target value [0.499999]
# prediction value [0.99856732]
# target value [0.60399879]
# prediction value [1.06780646]
# target value [0.19459961]
# prediction value [1.09563748]
# target value [0.3499993]
# prediction value [0.79244607]
# target value [0.61119878]
# prediction value [0.76843013]
# target value [0.32579935]
# prediction value [0.9085701]
# target value [0.14739971]
# prediction value [0.93662558]
# target value [0.26159948]
# prediction value [1.12723959]
# target value [0.41899916]
# prediction value [0.8974026]
# target value [0.4011992]
# prediction value [0.63890165]
# target value [0.35879928]
# prediction value [0.83907507]
# target value [0.5499989]
# prediction value [0.84537162]
# target value [0.46619907]
# prediction value [0.75957392]
# target value [0.3519993]
# prediction value [0.97174387]
# target value [0.2479995]
# prediction value [1.10955423]
# target value [0.23819952]
# prediction value [0.8278931]
# target value [0.39679921]
# prediction value [0.80974399]
# target value [0.1499997]
# prediction value [0.72112953]
# target value [0.26939946]
# prediction value [0.78864572]
# target value [0.23279953]
# prediction value [0.73198368]
# target value [0.50759898]
# prediction value [0.78570479]
# target value [0.11719977]
# prediction value [1.04103924]
# target value [0.59319881]
# prediction value [1.09535662]
# target value [0.24699951]
# prediction value [1.13489627]
# target value [1.]
# prediction value [0.99262984]
# target value [0.72179856]
# prediction value [1.03965796]
# target value [0.19639961]
# prediction value [0.88097781]
# target value [0.18779962]
# prediction value [0.69931665]
# target value [0.2475995]
# prediction value [0.81811919]
# target value [0.31759936]
# prediction value [0.95382167]
# target value [0.33599933]
# prediction value [0.94976371]
# target value [1.]
# prediction value [0.87379252]
# target value [0.44239912]
# prediction value [0.70856789]
# target value [0.28259943]
# prediction value [0.96071901]
# target value [0.11099978]
# prediction value [0.7752964]
# target value [0.53319893]
# prediction value [1.02225836]
# target value [0.42679915]
# prediction value [0.79280089]
# target value [0.0975998]
# prediction value [0.87812018]
# target value [0.26919946]
# prediction value [0.90743345]
# target value [0.57919884]
# prediction value [1.01564886]
# target value [0.43759912]
# prediction value [0.79253445]
# target value [0.14459971]
# prediction value [0.76352237]
# target value [0.49039902]
# prediction value [0.93003389]
# target value [0.16219968]
# prediction value [1.04682502]
# target value [0.49259901]
# prediction value [0.74976869]
# target value [0.2019996]
# prediction value [0.73639551]
# target value [0.499999]
# prediction value [0.92647731]
# target value [0.47859904]
# prediction value [0.81730927]
# target value [0.54379891]
# prediction value [0.82492992]
# target value [0.36259927]
# prediction value [0.76438595]
# target value [0.09499981]
# prediction value [0.87847287]
# target value [0.38139924]
# prediction value [0.73967706]
# target value [0.1517997]
# prediction value [0.77647856]
# target value [0.44059912]
# prediction value [0.92428989]
# target value [0.38919922]
# prediction value [0.92499036]
# target value [0.31699937]
# prediction value [1.02543796]
# target value [0.14719971]
# prediction value [0.97373734]
# target value [0.96439807]
# prediction value [0.83714368]
# target value [0.47499905]
# prediction value [1.01921793]
# target value [0.12079976]
# prediction value [0.76478152]
# target value [0.16119968]
# prediction value [0.67120185]
# target value [0.14619971]
# prediction value [0.89699182]
# target value [1.]
# prediction value [0.78093679]
# target value [0.48859902]
# prediction value [1.04636888]
# target value [0.41419917]
# prediction value [0.94552008]
# target value [0.18759962]
# prediction value [0.79743177]
# target value [0.32599935]
# prediction value [0.78665236]
# target value [0.29379941]
# prediction value [0.75510778]
# target value [0.54259891]
# prediction value [0.96444091]
# target value [0.6499987]
# prediction value [0.73305044]
# target value [0.33759932]
# prediction value [0.80583798]
# target value [0.38499923]
# prediction value [0.84835054]
# target value [0.63319873]
# prediction value [0.7237078]
# target value [0.63619873]
# prediction value [0.97531464]
# target value [0.2481995]
# prediction value [0.93075431]
# target value [0.41659917]
# prediction value [0.74842572]
# target value [0.51859896]
# prediction value [1.04586771]
# target value [0.27139946]
# prediction value [1.14504676]
# target value [0.72139856]
# prediction value [1.0156302]
# target value [0.13939972]
# prediction value [1.06161019]
# target value [0.29319941]
# prediction value [0.9316972]
# target value [0.21659957]
# prediction value [0.87913943]
# target value [0.36339927]
# prediction value [1.03452014]
# target value [0.66699867]
# prediction value [0.74522676]
# target value [0.29159942]
# prediction value [0.79524915]
# target value [0.44099912]
# prediction value [0.7334227]
# target value [0.41819916]
# prediction value [0.85948047]
# target value [0.998198]
# prediction value [0.85542068]
# target value [0.45779908]
# prediction value [1.07212869]
# target value [0.19659961]
# prediction value [0.7453921]
# target value [0.17599965]
# prediction value [0.67877725]
# target value [0.66659867]
# prediction value [0.72431904]
# target value [0.78979842]
# prediction value [0.833485]
# target value [0.30579939]
# prediction value [0.99973336]
# target value [0.80379839]
# prediction value [0.84520097]
# target value [0.4483991]
# prediction value [1.05566715]
# target value [0.50599899]
# prediction value [0.89334955]
# target value [0.39419921]
# prediction value [0.93523426]
# target value [0.53479893]
# prediction value [0.9220859]
# target value [0.31399937]
# prediction value [0.94895486]
# target value [0.77219846]
# prediction value [0.75163483]
# target value [0.10639979]
# prediction value [0.89708578]
# target value [0.18139964]
# prediction value [0.99804086]
# target value [0.22319955]
# prediction value [0.8449849]
# target value [0.63639873]
# prediction value [0.8141941]
# target value [0.64139872]
# prediction value [0.79217644]
# target value [0.44379911]
# prediction value [0.65678497]
# target value [0.23519953]
# prediction value [0.65248667]
# target value [0.39659921]
# prediction value [0.73885272]
# target value [0.45919908]
# prediction value [0.81885825]
# target value [0.28459943]
# prediction value [0.93353139]
# target value [0.38379923]
# prediction value [0.88082775]
# target value [0.28519943]
# prediction value [0.64369869]
# target value [0.31219938]
# prediction value [0.90038499]
# target value [0.28759942]
# prediction value [0.75539378]
# target value [0.30879938]
# prediction value [0.64303965]
# target value [0.21399957]
# prediction value [0.53878256]
# target value [0.09499981]
# prediction value [0.76807993]
# target value [0.23559953]
# prediction value [1.04522066]
# target value [0.31759936]
# prediction value [0.72635006]
# target value [0.2999994]
# prediction value [0.9242433]
# target value [0.39139922]
# prediction value [0.8393471]
# target value [0.5977988]
# prediction value [0.76204101]
# target value [0.58139884]
# prediction value [0.78514856]
# target value [0.13919972]
# prediction value [1.02453941]
# target value [0.30499939]
# prediction value [0.90381154]
# target value [0.35419929]
# prediction value [0.75272663]
# target value [0.19399961]
# prediction value [0.75818781]
# target value [0.44359911]
# prediction value [0.78120065]
# target value [0.38259923]
# prediction value [0.89307349]
# ...
# prediction value [1.0114286]
# target value [0.2005996]
# prediction value [0.99279089]
# target value [0.51419897]
# prediction value [0.86108615]
# target value [0.41619917]
# prediction value [0.93403056]
# target value [0.2499995]
# prediction value [0.9839582]
# target value [0.44479911]
# prediction value [0.82713769]
# target value [0.60319879]
# prediction value [0.79633359]
# target value [0.17499965]
# prediction value [1.0532605]
# target value [0.23399953]
# prediction value [0.98598797]
# target value [0.75999848]
# prediction value [0.9622755]
# target value [0.23659953]
# prediction value [0.90875308]
# target value [0.1983996]
# prediction value [0.9009397]
# target value [0.4007992]
# prediction value [0.99322055]
# target value [0.33199934]
# prediction value [0.74641423]
# target value [0.22499955]
# prediction value [0.91159154]
# target value [0.50279899]
# prediction value [0.77366868]
# target value [0.17159966]
# prediction value [0.70001066]
# target value [0.18719963]
# prediction value [0.81507228]
# target value [0.54699891]
# prediction value [0.8652785]
# target value [0.82359835]
# prediction value [0.97264144]
# target value [0.89619821]
# prediction value [1.00072972]
# target value [0.37139926]
# prediction value [0.90443624]
# target value [0.51599897]
# prediction value [1.04221757]
# target value [0.5485989]
# prediction value [0.9360081]
# target value [0.33139934]
# prediction value [0.89611359]
# target value [0.27639945]
# prediction value [0.78009063]
# target value [0.53959892]
# prediction value [0.81967415]
# target value [0.4503991]
# prediction value [0.92349659]
# target value [0.31639937]
# prediction value [0.96310677]
# target value [0.80999838]
# prediction value [1.0836053]
# target value [0.27499945]
# prediction value [0.88371281]
# target value [0.16779966]
# prediction value [0.89120018]
# target value [0.35439929]
# prediction value [0.89162796]
# target value [0.28119944]
# prediction value [0.82004428]
# target value [0.23219954]
# prediction value [1.17291416]
# target value [1.]
# prediction value [0.97641162]
# target value [0.18119964]
# prediction value [0.74106166]
# target value [0.48439903]
# prediction value [0.68931101]
# target value [0.27899944]
# prediction value [0.78891844]
# target value [0.21439957]
# prediction value [0.70258957]
# target value [0.14699971]
# prediction value [0.97702669]
# target value [0.34199932]
# prediction value [1.04397009]
# target value [0.87359825]
# prediction value [0.86205553]
# target value [0.41879916]
# prediction value [0.71880456]
# target value [0.10959978]
# prediction value [0.99796066]
# target value [0.28679943]
# prediction value [0.66670009]
# target value [1.]
# prediction value [0.77665928]
# target value [1.]
# prediction value [0.94058879]
# target value [0.23459953]
# prediction value [0.73482681]
# target value [0.30619939]
# prediction value [0.88868895]
# target value [0.35539929]
# prediction value [0.88488188]
# target value [0.52059896]
# prediction value [0.71787009]
# target value [0.17159966]
# prediction value [0.61551049]
# target value [0.36779926]
# prediction value [0.92427629]
# target value [0.39419921]
# prediction value [0.87917609]
# target value [0.41079918]
# prediction value [0.81310006]
# target value [0.30379939]
# prediction value [1.12518118]
# target value [1.]
# prediction value [0.88493544]
# target value [0.31619937]
# prediction value [0.94191137]
# target value [0.30699939]
# prediction value [0.88199005]
# target value [0.37019926]
# prediction value [0.626714]
# target value [0.20759958]
# prediction value [1.06909109]
# target value [0.22499955]
# prediction value [0.73986695]
# target value [1.]
# prediction value [0.78558397]
# target value [0.46859906]
# prediction value [0.77915511]
# target value [0.28759942]
# prediction value [0.83676054]
# target value [0.67859864]
# prediction value [0.91650499]
# target value [0.29439941]
# prediction value [0.89784744]
# target value [0.22499955]
# prediction value [0.80507753]
# target value [0.81239838]
# prediction value [0.66202288]
# target value [0.28859942]
# prediction value [0.91156676]
# target value [0.1485997]
# prediction value [0.79766679]
# target value [0.55759888]
# prediction value [0.72675591]
# target value [0.21759956]
# prediction value [0.90707034]
# target value [0.26659947]
# prediction value [0.92847103]
# target value [0.43179914]
# prediction value [0.83137343]
# target value [0.12619975]
# prediction value [1.02877166]
# target value [0.30759938]
# prediction value [0.84098156]
# target value [0.24439951]
# prediction value [0.92765258]
# target value [0.82939834]
# prediction value [0.95484076]
# target value [0.20899958]
# prediction value [0.74622872]
# target value [0.18239964]
# prediction value [0.95331535]
# target value [0.38079924]
# prediction value [1.05675946]
# target value [0.22419955]
# prediction value [0.72907697]
# target value [0.32179936]
# prediction value [0.98403]
# target value [0.17319965]
# prediction value [0.93354924]
# target value [0.36099928]
# prediction value [1.00590987]
# target value [0.29579941]
# prediction value [0.79921227]
# target value [0.19679961]
# prediction value [0.82534548]
# target value [0.46659907]
# prediction value [1.11325722]
# target value [0.75319849]
# prediction value [0.86110061]
# target value [0.17219966]
# prediction value [0.7512735]
# target value [0.60599879]
# prediction value [0.73082617]
# target value [0.71759856]
# prediction value [0.75761652]
# target value [0.26139948]
# prediction value [0.86310143]
# target value [0.3499993]
# prediction value [0.95735935]
# target value [0.86959826]
# prediction value [0.80096114]
# target value [0.47139906]
# prediction value [0.89856395]
# target value [0.14399971]
# prediction value [0.95571007]
# target value [0.57319885]
# prediction value [0.95016464]
# target value [0.13179974]
# prediction value [0.69194481]
# target value [0.35399929]
# prediction value [0.94326746]
# target value [0.21839956]
# prediction value [0.83470638]
# target value [0.46439907]
# prediction value [0.73744014]
# target value [0.31879936]
# prediction value [1.12042726]
# target value [0.43679913]
# prediction value [0.81959194]
# target value [0.43499913]
# prediction value [0.92718984]
# target value [0.31559937]
# prediction value [0.82129035]
# target value [0.2015996]
# prediction value [0.72552027]
# target value [0.28519943]
# prediction value [0.9392094]
# target value [0.3983992]
# prediction value [0.77600376]
# target value [0.16919966]
# prediction value [0.94395246]
# target value [0.43339913]
# prediction value [0.96997478]
# target value [0.37499925]
# prediction value [0.83644553]
# target value [0.14459971]
# prediction value [0.87789256]
# target value [0.52799894]
# prediction value [0.88676286]
# target value [0.6023988]
# prediction value [0.90413911]
# target value [0.37259925]
# prediction value [1.07113545]
# target value [0.25839948]
# prediction value [0.82464402]
# target value [0.17559965]
# prediction value [0.9283487]
# target value [0.15659969]
# prediction value [0.96608941]
# target value [0.27699945]
# prediction value [0.94907747]
# target value [0.42079916]
# prediction value [0.93432159]
# target value [0.2021996]
# prediction value [0.98830007]
# target value [0.32379935]
# prediction value [0.96092527]
# target value [0.34019932]
# prediction value [0.82168109]
# target value [0.26079948]
# prediction value [0.85161067]
# target value [0.32099936]
# prediction value [1.11934781]
# target value [0.17979964]
# prediction value [0.94055761]
# target value [0.34679931]
# prediction value [0.75933749]
# target value [0.47119906]
# prediction value [1.05070991]
# target value [0.33299933]
# prediction value [0.75437402]
# target value [0.26439947]
# prediction value [1.06134512]
# target value [0.63699873]
# prediction value [0.94313949]
# target value [0.29039942]
# prediction value [0.9596305]
# target value [0.21999956]
# prediction value [1.02579152]
# target value [0.33859932]
# prediction value [0.89009654]
# target value [0.78799842]
# prediction value [0.95410946]
# target value [0.47739905]
# prediction value [0.72230094]
# target value [0.46959906]
# prediction value [0.91440517]
# target value [0.19199962]
# prediction value [0.92273509]
# target value [0.31459937]
# prediction value [0.73742964]
# target value [0.18459963]
# prediction value [1.02623953]
# target value [0.20299959]
# prediction value [1.03625342]
# target value [0.63679873]
# prediction value [0.68360643]
# target value [0.26259947]
# prediction value [0.76451866]
# target value [0.21079958]
# prediction value [0.95050787]
# target value [0.32219936]
# prediction value [0.8105719]
# target value [0.74239852]
# prediction value [1.06165942]
# target value [0.67959864]
# prediction value [0.60402171]
# target value [0.34099932]
# prediction value [0.87853023]
# target value [0.23759952]
# prediction value [0.80455942]
# target value [0.58739883]
# prediction value [1.09406569]
# target value [0.52499895]
# prediction value [0.98167928]
# target value [0.13079974]
# prediction value [0.80359693]
# target value [0.10819978]
# prediction value [0.76443951]
# target value [0.30879938]
# prediction value [0.80792152]
# target value [0.32499935]
# prediction value [0.95868124]
# target value [0.41039918]
# prediction value [1.09728563]
# target value [0.81079838]
# prediction value [0.8162487]
# target value [0.46339907]
# prediction value [0.8157606]
# target value [0.21999956]
# prediction value [0.76133054]
# target value [0.2507995]
# prediction value [0.97167981]
# target value [0.14379971]
# prediction value [1.0643148]
# target value [0.28119944]
# prediction value [0.69781208]
# target value [0.12879974]
# prediction value [0.68926257]
# target value [0.30799938]
# prediction value [0.70337105]
# target value [0.54459891]
# prediction value [0.78238954]
# target value [0.22579955]
# prediction value [0.93190711]
# target value [0.12559975]
# prediction value [1.02442518]
# target value [0.37499925]
# prediction value [0.84155437]
# target value [0.54319891]
# prediction value [0.95017832]
# target value [0.500399]
# prediction value [0.941774]
# target value [0.18159964]
# prediction value [1.01056611]
# target value [0.45479909]
# prediction value [0.97994462]
# target value [0.57499885]
# prediction value [0.9183955]
# target value [0.52139896]
# prediction value [0.77408202]
# target value [0.36399927]
# prediction value [0.95347558]
# target value [0.58259883]
# prediction value [0.89186859]
# target value [0.46919906]
# prediction value [0.81510317]
# target value [0.28159944]
# prediction value [0.66599948]
# target value [0.23439953]
# prediction value [0.93312675]
# target value [0.53739893]
# prediction value [0.8705063]
# target value [0.58079884]
# prediction value [1.06110618]
# target value [0.77639845]
# prediction value [0.7332617]
# target value [0.40979918]
# prediction value [0.73492742]
# target value [0.52819894]
# prediction value [0.96124672]
# target value [0.12819974]
# prediction value [0.93238618]
# target value [0.13979972]
# prediction value [1.06774622]
# target value [0.18119964]
# prediction value [1.03794156]
# target value [0.499999]
# prediction value [0.7446134]
# target value [0.55519889]
# prediction value [0.88463619]
# target value [0.22359955]
# prediction value [0.89132506]
# target value [0.25839948]
# prediction value [1.00064155]
# target value [0.12579975]
# prediction value [0.63210955]
# target value [0.32499935]
# prediction value [1.02462731]
# target value [0.55719889]
# prediction value [0.71015462]
# target value [0.33019934]
# prediction value [0.91053828]
# target value [0.68359863]
# prediction value [1.01439673]
# target value [0.19099962]
# prediction value [0.76270877]
# target value [0.10939978]
# prediction value [0.88795166]
# target value [0.27399945]
# prediction value [0.94477658]
# target value [0.35379929]
# prediction value [0.7840253]
# target value [0.27499945]
# prediction value [0.7341909]
# target value [0.55599889]
# prediction value [0.95717709]
# target value [0.6521987]
# prediction value [0.72968244]
# target value [0.25319949]
# prediction value [1.07202293]
# target value [0.3499993]
# prediction value [0.86033124]
# target value [0.6999986]
# prediction value [1.03392651]
# target value [0.20579959]
# prediction value [0.90073911]
# target value [0.26999946]
# prediction value [1.04403592]
# target value [0.35879928]
# prediction value [0.74505631]
# target value [0.34479931]
# prediction value [0.97768217]
# target value [0.7499985]
# prediction value [0.7168341]
# target value [0.28239944]
# prediction value [0.74099666]
# target value [0.27519945]
# prediction value [0.99105734]
# target value [0.66559867]
# prediction value [0.92311845]
# target value [0.17259965]
# prediction value [1.07787746]
# target value [0.29199942]
# prediction value [0.79859186]
# target value [0.46519907]
# prediction value [1.1177675]
# target value [0.43899912]
# prediction value [0.7612918]
# target value [0.49219902]
# prediction value [0.96366138]
# target value [0.45459909]
# prediction value [0.62907027]
# target value [0.40339919]
# prediction value [0.94979967]
# target value [0.32839934]
# prediction value [0.84455679]
# target value [0.31139938]
# prediction value [0.78969135]
# target value [0.35679929]
# prediction value [0.90648014]
# target value [0.37599925]
# prediction value [1.1315281]
# target value [0.23319953]
# prediction value [1.05660992]
# target value [0.55839888]
# prediction value [0.88676149]
# target value [0.13899972]
# prediction value [0.78166558]
# target value [0.25559949]
# prediction value [0.93396421]
# target value [0.51659897]
# prediction value [1.0190456]
# target value [0.35999928]
# prediction value [0.94234675]
# target value [0.23519953]
# prediction value [0.71428055]
# target value [0.48199904]
# prediction value [0.82080566]
# target value [0.33859932]
# prediction value [0.79182595]
# target value [0.58859882]
# prediction value [0.97956349]
# target value [0.46199908]
# prediction value [1.07315255]
# target value [0.26039948]
# prediction value [0.80888259]
# target value [0.18059964]
# prediction value [1.13550038]
# target value [0.69739861]
# prediction value [1.0065014]
# target value [0.21779956]
# prediction value [1.01792183]
# target value [0.22659955]
# prediction value [0.94365295]
# target value [0.54699891]
# prediction value [0.90643226]
# target value [0.86899826]
# prediction value [1.07591654]
# target value [0.68439863]
# prediction value [0.95181116]
# target value [1.]
# prediction value [1.11633098]
# target value [0.50379899]
# prediction value [0.9824922]
# target value [0.28979942]
# prediction value [1.05010301]
# target value [0.42499915]
# prediction value [0.86468859]
# target value [0.56459887]
# prediction value [0.79583353]
# target value [0.46559907]
# prediction value [0.91692178]
# target value [0.42399915]
# prediction value [0.77128668]
# target value [0.2999994]
# prediction value [0.77833562]
# target value [0.19239962]
# prediction value [0.76450441]
# target value [0.78439843]
# prediction value [0.839555]
# target value [0.11039978]
# prediction value [0.88689109]
# target value [0.34119932]
# prediction value [0.8471092]
# target value [0.16619967]
# prediction value [1.12908412]
# target value [1.]
# prediction value [1.07121091]
# target value [0.25999948]
# prediction value [1.04644168]
# target value [0.19399961]
# prediction value [0.81986809]
# target value [0.54259891]
# prediction value [0.76389321]
# target value [0.57679885]
# prediction value [0.95091863]
# target value [0.20279959]
# prediction value [0.99953345]
# target value [0.61819876]
# prediction value [1.04315569]
# target value [0.82299835]
# prediction value [1.03964665]
# target value [1.]
# prediction value [0.70243322]
# target value [0.63219874]
# prediction value [0.90799865]
# target value [0.27499945]
# prediction value [0.84493867]
# target value [0.25779948]
# prediction value [0.73292133]
# target value [0.21739957]
# prediction value [0.74347967]
# target value [0.26959946]
# prediction value [1.06328052]
# target value [0.63699873]
# prediction value [0.69594182]
# target value [0.9007982]
# prediction value [1.11974361]
# target value [1.]
# prediction value [0.83165076]
# target value [0.46119908]
# prediction value [0.76693257]
# target value [0.48039904]
# prediction value [0.74160371]
# target value [0.48359903]
# prediction value [0.7608086]
# target value [0.3481993]
# prediction value [0.73049857]
# target value [0.73739853]
# prediction value [0.72053901]
# target value [0.19279961]
# prediction value [0.95350768]
# target value [0.33659933]
# prediction value [1.10343931]
# target value [0.55699889]
# prediction value [0.79578066]
# target value [0.35379929]
# prediction value [1.06581175]
# target value [0.28419943]
# prediction value [0.75882126]
# target value [0.15319969]
# prediction value [0.8491806]
# target value [0.16619967]
